# %%
import sqlite3
import pandas as pd
import numpy as np

# %%
url="../../exercises/Ex_Files_SQL_Code_Challenges/Exercise Files/Ch01/restaurant.db"

# %%
con=sqlite3.connect(url)

# %%
cursor = con.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('EventsLocations',), ('Events',), ('CustomersEvents',), ('CustomersDishes',), ('Customers',), ('sqlite_sequence',), ('Dishes',), ('OrdersDishes',), ('Reservations',), ('Orders',), ('response',)]

# %%
pd.read_sql_query("select * from Customers", con).head()
# Out:
#    CustomerID FirstName LastName                     Email  \
# 0           1     Maggi   Domney   mdomney0@wisdompets.com
# 1           2    Javier    Dawks   jdawks1@red30design.com
# 2           3     Aleen    Fasey   afasey2@kinetecoinc.com
# 3           4    Taylor  Jenkins  tjenkins@rouxacademy.org
# 4           5    Imogen   Kabsch   ikabsch@landonhotel.com
#
#                    Address             City State         Phone    Birthday  \
# 0    53177 Fieldstone Pass   San Bernardino    CA  760-702-5469  1938-10-11
# 1        25629 Brown Trail         Hartford    CT  860-906-1459  1953-11-21
# 2  41967 Mockingbird Court       Boca Raton    FL  561-410-2222  1900-08-10
# 3       968 Bartillon Park  Fort Lauderdale    FL  954-294-7424  1961-05-02
# 4         222 Hudson Point         Anderson    SC  864-326-7456  1919-08-27
#
#    FavoriteDish
# 0            15
# 1            13
# 2             3
# 3             8
# 4            17

# %%
pd.read_sql_query("SELECT lastname,firstname,email from customers order by lastname asc", con).head()
# Out:
#    LastName FirstName                       Email
# 0     Algar   Giraldo    galgar21@kinetecoinc.com
# 1  Alphonso   Gustave  galphonso28@wisdompets.com
# 2    Annett     Romeo        rannett1e@samoca.org
# 3   Aspinal     Herby   haspinals@red30design.com
# 4   Attwool     Emlyn    eattwoolt@hplussport.com

# %%
cursor.execute("CREATE TABLE response (customerID int not null, response int, foreign key (customerID) REFERENCES customers(CustomerID));")

# %%
pd.read_sql_query("select * from dishes",con).head()
# Out:
#    DishID                          Name  \
# 0       1         Parmesan Deviled Eggs
# 1       2  Artichokes with Garlic Aioli
# 2       3             French Onion Soup
# 3       4            Mini Cheeseburgers
# 4       5       Panko Stuffed Mushrooms
#
#                                          Description  Price       Type
# 0  These delectable little bites are made with or...    8.0  Appetizer
# 1  Our artichokes are brushed with an olive oil a...    9.0  Appetizer
# 2  Caramelized onions slow cooked in a savory bro...    7.0       Main
# 3  These mini cheeseburgers are served on a fresh...    8.0       Main
# 4  Large mushroom caps are filled a savory cream ...    7.0  Appetizer

# %%
pd.read_sql_query("select * from dishes order by price asc",con).head()
# Out:
#    DishID                    Name  \
# 0      21    Pomegranate Iced Tea
# 1      18               Apple Pie
# 2      17  Chocolate Chip Brownie
# 3      20  Tropical Blue Smoothie
# 4      22              Cafe Latte
#
#                                          Description  Price      Type
# 0  Our unique blend of pomegranate juice, black R...    4.0  Beverage
# 1  Made with local granny smith apples to bring y...    5.0   Dessert
# 2  A warm chocolate chip brownie served with choc...    6.0   Dessert
# 3  This blueberry mint-based smoothie is refreshi...    6.0  Beverage
# 4  Our house blend of espresso and foamed milk. C...    6.0  Beverage

# %%
pd.read_sql_query("select * from dishes where type<>'Beverage'order by type",con)
# Out:
#     DishID                          Name  \
# 0        1         Parmesan Deviled Eggs
# 1        2  Artichokes with Garlic Aioli
# 2        5       Panko Stuffed Mushrooms
# 3       13        Barbecued Tofu Skewers
# 4       15                  Creme Brulee
# 5       16                    Cheesecake
# 6       17        Chocolate Chip Brownie
# 7       18                     Apple Pie
# 8       19              Mixed Berry Tart
# 9        3             French Onion Soup
# 10       4            Mini Cheeseburgers
# 11       6                 Garden Buffet
# 12       7                   House Salad
# 13       8                  Chef's Salad
# 14       9           Quinoa Salmon Salad
# 15      10                Classic Burger
# 16      11  Tomato Bruschetta Tortellini
# 17      12             Handcrafted Pizza
# 18      14         Fiesta Family Platter
#
#                                           Description  Price       Type
# 0   These delectable little bites are made with or...   8.00  Appetizer
# 1   Our artichokes are brushed with an olive oil a...   9.00  Appetizer
# 2   Large mushroom caps are filled a savory cream ...   7.00  Appetizer
# 3   Our barbecued skewers include tofu, cherry tom...   9.99  Appetizer
# 4   Elegantly crafted creamy vanilla custard with ...   9.00    Dessert
# 5   Our New York Style Cheesecake is rich, smooth,...   9.00    Dessert
# 6   A warm chocolate chip brownie served with choc...   6.00    Dessert
# 7   Made with local granny smith apples to bring y...   5.00    Dessert
# 8   Raspberries, blueberries, and strawberries on ...   7.00    Dessert
# 9   Caramelized onions slow cooked in a savory bro...   7.00       Main
# 10  These mini cheeseburgers are served on a fresh...   8.00       Main
# 11  Choose from our fresh local, organically grown...   9.99       Main
# 12  Our house salad is made with romaine lettuce a...   7.00       Main
# 13  The chef's salad has cucumber, tomatoes, red o...   9.00       Main
# 14  Our quinoa salad is served with quinoa, tomato...   9.99       Main
# 15  Our classic burger is made with 100% pure angu...   9.99       Main
# 16  This classic cheese tortellini is cooked in a ...   9.99       Main
# 17  Our thin crust pizzas are made fresh daily and...   9.99       Main
# 18  This platter is perfect for sharing! Enjoy our...   9.99       Main

# %%
pd.read_sql_query("select * from customers",con)
# Out:
#      CustomerID FirstName   LastName                         Email  \
# 0             1     Maggi     Domney       mdomney0@wisdompets.com
# 1             2    Javier      Dawks       jdawks1@red30design.com
# 2             3     Aleen      Fasey       afasey2@kinetecoinc.com
# 3             4    Taylor    Jenkins      tjenkins@rouxacademy.org
# 4             5    Imogen     Kabsch       ikabsch@landonhotel.com
# ..          ...       ...        ...                           ...
# 96           97      Herb  McParland  hmcparland2o@rouxacademy.org
# 97           98      Clem      Durdy       cdurdy2p@hplussport.com
# 98           99      Kala  Stevenson    kstevenson@landonhotel.com
# 99          100    Blythe     Leggan     bleggan2r@rouxacademy.org
# 100         101     Julia  Kauffmann                       j@gmail
#
#                      Address             City State         Phone    Birthday  \
# 0      53177 Fieldstone Pass   San Bernardino    CA  760-702-5469  1938-10-11
# 1          25629 Brown Trail         Hartford    CT  860-906-1459  1953-11-21
# 2    41967 Mockingbird Court       Boca Raton    FL  561-410-2222  1900-08-10
# 3         968 Bartillon Park  Fort Lauderdale    FL  954-294-7424  1961-05-02
# 4           222 Hudson Point         Anderson    SC  864-326-7456  1919-08-27
# ..                       ...              ...   ...           ...         ...
# 96            39 Algoma Park          Chicago    IL  630-950-3309  1916-12-25
# 97          594 Bonner Point       Des Moines    IA  515-680-5018  1988-03-10
# 98         95 Waywood Street       Huntington    WV  304-681-5208  1947-11-30
# 99     1622 Golf Course Hill       Montgomery    AL  334-770-7364  1996-06-11
# 100             1550 Lava Dr        Milwaukie    OR   555-555-555  1976-04-02
#
#      FavoriteDish
# 0              15
# 1              13
# 2               3
# 3               8
# 4              17
# ..            ...
# 96             14
# 97             16
# 98              5
# 99              5
# 100            10
#
# [101 rows x 10 columns]

# %%
con.execute('insert into customers values(101,"Julia","Kauffmann","j@gmail","1550 Lava Dr","Milwaukie","OR","555-555-555","1976-04-02","10")')

# %%
pd.read_sql_query("select * from customers where lastname='Tapley' and firstname='Asher'",con)
# Out:
#    CustomerID FirstName LastName                      Email  \
# 0          92     Asher   Tapley  atapley2j@kinetecoinc.com
#
#                 Address     City State         Phone    Birthday  FavoriteDish
# 0  720 Saint Paul Plaza  Hialeah    FL  786-938-4977  1959-08-05             7

# %%
pd.read_sql_query('select * from response',con)
# Out:
# Empty DataFrame
# Columns: [customerID, response]
# Index: []

# %%
con.execute("insert into response values((select customerid from customers where lastname='Tapley' and firstname='Asher'),3)")

# %%
pd.read_sql_query('select * from response',con)
# Out:
#    customerID  response
# 0          92         4

# %%
con.execute('update response set response=4 where customerID=92')

# %%
pd.read_sql_query('select * from reservations',con)
# Out:
#       ReservationID  CustomerID                 Date  PartySize
# 0                 1          74  2016-06-01 15:30:00          6
# 1                 2          67  2016-06-02 13:30:00          2
# 2                 3          16  2016-06-04 08:00:00          4
# 3                 4          87  2016-06-04 19:30:00          5
# 4                 5          29  2016-06-06 13:00:00          1
# ...             ...         ...                  ...        ...
# 1995           1996          54  2020-06-28 17:00:00          4
# 1996           1997          18  2020-06-29 11:00:00          1
# 1997           1998          54  2020-06-29 20:30:00          2
# 1998           1999          86  2020-06-30 13:30:00          6
# 1999           2000          86  2020-06-30 21:30:00          4
#
# [2000 rows x 4 columns]

# %%
pd.read_sql_query('select r.customerid,r.date, r.partysize, c.firstname,c.lastname \
from customers c \
join reservations r \
on r.customerid=c.customerid \
where c.lastname like "ste%" and r.date like "%6-14%"',con)
# Out:
#    CustomerID                 Date  PartySize FirstName    LastName
# 0          14  2020-06-14 18:30:00          4      Paco  Stephenson

# %%
con.execute('\
insert into customers(firstname,lastname,email,phone) \
values ("Sam","McAdams","smac@gmail.com","555-555-5555")')

# %%
pd.read_sql_query('\
select * from customers where lastname="McAdams"',con)
# Out:
#    CustomerID FirstName LastName           Email Address  City State  \
# 0         101       Sam  McAdams  smac@gmail.com    None  None  None
#
#           Phone Birthday FavoriteDish
# 0  555-555-5555     None         None

# %%
pd.read_sql_query('\
select * from reservations',con)
# Out:
#       ReservationID  CustomerID                 Date  PartySize
# 0                 1          74  2016-06-01 15:30:00          6
# 1                 2          67  2016-06-02 13:30:00          2
# 2                 3          16  2016-06-04 08:00:00          4
# 3                 4          87  2016-06-04 19:30:00          5
# 4                 5          29  2016-06-06 13:00:00          1
# ...             ...         ...                  ...        ...
# 1996           1997          18  2020-06-29 11:00:00          1
# 1997           1998          54  2020-06-29 20:30:00          2
# 1998           1999          86  2020-06-30 13:30:00          6
# 1999           2000          86  2020-06-30 21:30:00          4
# 2000           2001         101  2016-14-02 13:30:00          6
#
# [2001 rows x 4 columns]

# %%
con.execute('insert into reservations (customerid,date,partysize) \
values (101,"2016-14-02 13:30:00",6)')

# %%
con.execute('update reservations set reservationid=2001 where customerid=101')

# %%
pd.read_sql_query('\
select * from customers where lastname="Hundey"',con)
# Out:
#    CustomerID FirstName LastName                      Email          Address  \
# 0          70   Loretta   Hundey  lhundey1x@kinetecoinc.com  6939 Elka Place
#
#           City State         Phone    Birthday  FavoriteDish
# 0  Los Angeles    CA  310-730-8619  1945-08-14            18

# %%
pd.read_sql_query('\
select * from orders',con)
# Out:
#      OrderID  CustomerID            OrderDate
# 0          1          77  2016-06-01 20:59:00
# 1          2          33  2016-06-02 19:35:00
# 2          3           7  2016-06-03 13:51:00
# 3          4          18  2016-06-04 21:49:00
# 4          5          34  2016-06-05 21:40:00
# ..       ...         ...                  ...
# 995      996          29  2020-06-26 10:50:00
# 996      997          13  2020-06-27 09:36:00
# 997      998           4  2020-06-27 17:49:00
# 998      999          58  2020-06-28 16:42:00
# 999     1000          27  2020-06-28 18:19:00
#
# [1000 rows x 3 columns]

# %%
pd.read_sql_query('\
select * from dishes where name like "house%"',con).head(1)
# Out:
#    DishID         Name                                        Description  \
# 0       7  House Salad  Our house salad is made with romaine lettuce a...
#
#    Price  Type
# 0    7.0  Main

# %%
pd.read_sql_query('\
select * from ordersdishes',con).head(5)
# Out:
#    OrdersDishesID  OrderID  DishID
# 0               1        1      16
# 1               2        1      18
# 2               3        2       4
# 3               4        2       9
# 4               5        3      17

# %%
con.execute('insert into orders values (1001,70,"2020-06-28 18:19:00")')

# %%
con.execute('insert into ordersdishes (OrderID,DishID) values (1001,7)')

# %%
pd.read_sql_query('\
select * from ordersdishes where orderid=1001',con)
# Out:
#   OrdersDishesID  OrderID  DishID
# 0           None     1001      20
# 1           None     1001       8
# 2           None     1001       7

# %%
pd.read_sql_query('select a.orderID,sum(b.price) from ordersdishes a \
join dishes b \
on a.dishid=b.dishid where orderid=1001 \
group by orderid',con)
# Out:
#    OrderID  sum(b.price)
# 0     1001          22.0

# %%
pd.read_sql_query('\
select * from customers where firstname="Cleo"',con)
# Out:
#    CustomerID FirstName   LastName                         Email  \
# 0          42      Cleo  Goldwater  cgoldwater15@landonhotel.com
#
#               Address   City State         Phone    Birthday  FavoriteDish
# 0  9831 Evergreen Way  Tyler    TX  903-791-7266  1959-09-14             9

# %%
pd.read_sql_query('\
select * from dishes where name like "q%"',con)
# Out:
#    DishID                 Name  \
# 0       9  Quinoa Salmon Salad
#
#                                          Description  Price  Type
# 0  Our quinoa salad is served with quinoa, tomato...   9.99  Main

# %%
con.execute('update customers \
set favoritedish=9 where customerid=42')

# %%
pd.read_sql_query('\
select c.firstname,c.lastname,o.customerid,count(o.orderdate) as count from orders as o \
join customers as c on o.customerid=c.customerid \
group by o.customerid order by count desc limit 5',con)
# Out:
#   FirstName     LastName  CustomerID  count
# 0    Blythe       Leggan         100     20
# 1   Luciano       Winton          35     17
# 2      Yves  Dell'Abbate          27     16
# 3     Norby      Sleight          64     15
# 4    Oralla        Dayer          39     15

# %%
test=pd.DataFrame({'test':[3,3,4,2]})

# %%
test['test'].mean()
# Out:
# 3.0

# %%
np.sqrt(2/3)
# Out:
# 0.816496580927726
