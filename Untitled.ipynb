# %%
import pandas as pd
import sqlite3


def return_table(region,gender,generation,category):
    #set up sqlite
    connection = sqlite3.connect('flix.db')
    
    
    #assemble query
    option_count=0
    if region=='all' or gender=='all' or generation=='all':
        sql_query="select *, sum(cast(replace(view,',','') as integer)) as views from flix_shows"
    else:
         sql_query="select *,cast(replace(view,',','') as integer) as views from flix_shows"
    
    if region!='all' or gender!='all' or generation!='all' or category!='all':
        sql_query=sql_query+" where"
    
    if region!='all': 
        sql_query=sql_query+f" viewing_country='{region}'"
        option_count=1
    if gender!='all':
        if option_count>0: sql_query=sql_query+" and"
        sql_query=sql_query+f" gender='{gender}'"
        option_count=1
    if generation!='all':
        if option_count>0: sql_query=sql_query+" and"
        sql_query=sql_query+f" generation='{generation}'"
    if category!='all':
        if option_count>0: sql_query=sql_query+" and"
        sql_query=sql_query+f" category='{category}'"
        
    if region=='all' or gender=='all' or generation=='all':
        sql_query=sql_query+" group by title order by Views desc"
        
    df=pd.read_sql_query(sql_query,connection)
    
    #this is working but need to have views add up on group by but I want to keep the comma as well"
    
    return df

# %%
return_table('all','all','all','all')
# Out:
#                           title       view   category        country  \
# 0                       Friends  7,700,000    TV Show  United States
# 1                  Supernatural  1,200,000    TV Show  United States
# 2                     Mr. Robot  5,100,000    TV Show  United States
# 3                 Tom and Jerry    370,000    TV Show  United States
# 4                         Bones    520,000    TV Show  United States
# ..                          ...        ...        ...            ...
# 231                     Chicago      1,000      Movie  United States
# 232  Best Exotic Marigold Hotel      1,000  Franchise  United States
# 233     All the President's Men      1,000      Movie  United States
# 234          All the King's Men      1,000      Movie  United States
# 235              Into the Woods          0      Movie  United States
#
#         premiere                      genre    generation gender  \
# 0     09/22/1994             |Comedy|Sitcom  generation-z    men
# 1     09/13/2005      |Fantasy|Supernatural  generation-z    men
# 2     05/27/2015         |Drama|Crime Drama  generation-z    men
# 3     02/10/1940  |Animation|For Older Kids  generation-z    men
# 4     09/13/2005    |Crime|Case of the week  generation-z    men
# ..           ...                        ...           ...    ...
# 231   12/26/2002               |Music|Crime  generation-z    men
# 232  2011 – 2015                    |Comedy  generation-z    men
# 233   04/04/1976      |Thriller|Journalists  generation-z    men
# 234   09/10/2006                     |Drama  generation-z    men
# 235   12/25/2014             |Fantasy|Witch  generation-z    men
#
#     viewing_country      views
# 0            brazil  188792000
# 1            brazil   51632000
# 2           germany   40400000
# 3            brazil   33946000
# 4            brazil   30083000
# ..              ...        ...
# 231         germany      24000
# 232         germany      24000
# 233         germany      24000
# 234         germany      23000
# 235         germany          0
#
# [236 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-3-c8dac9921641> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 engine=create_engine('flix.db')
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     498     strategy = kwargs.pop("strategy", default_strategy)
#     499     strategy = strategies.strategies[strategy]
# --> 500     return strategy.create(*args, **kwargs)
#     501
#     502
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      52     def create(self, name_or_url, **kwargs):
#      53         # create url.URL object
# ---> 54         u = url.make_url(name_or_url)
#      55
#      56         plugins = u._instantiate_plugins(kwargs)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/url.py in make_url(name_or_url)
#     227
#     228     if isinstance(name_or_url, util.string_types):
# --> 229         return _parse_rfc1738_args(name_or_url)
#     230     else:
#     231         return name_or_url
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/url.py in _parse_rfc1738_args(name)
#     289     else:
#     290         raise exc.ArgumentError(
# --> 291             "Could not parse rfc1738 URL from string '%s'" % name
#     292         )
#     293
#
# ArgumentError: Could not parse rfc1738 URL from string 'flix.db'
