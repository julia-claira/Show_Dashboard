# %%
import sqlite3
import pandas as pd
connection = sqlite3.connect('../flix.db')
cursor=connection.cursor()

# %%
kidz=pd.read_sql_query("select * from flix_shows where generation='generation-z' and viewing_country='united-states'",connection)

# %%
kidz
# Out:
#                           title       view   category         country  \
# 0                   The Witcher  1,300,000    TV Show   United States
# 1                 Tom and Jerry    820,000    TV Show   United States
# 2               Stranger Things    790,000    TV Show   United States
# 3                Rick and Morty    620,000    TV Show   United States
# 4                  Breaking Bad    610,000    TV Show   United States
# ..                          ...        ...        ...             ...
# 460        The First Wives Club      1,000      Movie   United States
# 461              Gone Baby Gone      1,000      Movie   United States
# 462                  Life of Pi      1,000      Movie  United Kingdom
# 463  Best Exotic Marigold Hotel      1,000  Franchise   United States
# 464              Into the Woods          0      Movie   United States
#
#         premiere                           genre    generation gender  \
# ...

# %%
kidz=pd.read_csv('kidz.csv')

# %%
kidz=kidz.loc[~kidz['genre'].str.contains('CSI')]
kidz=kidz.loc[~kidz['title'].str.contains('Lie to Me')]

# %%
#kidz.loc[(kidz.title.str.contains('Star')) & (kidz.gender=='women'),'view']='385,000'
kidz.loc[kidz.genre.str.contains('Sci')] 
#kidz.iloc[0:50]
#kidz.loc[kidz['title'].str.contains('-')]
# Out:
#                           title     view category         country    premiere  \
# 1     Star Wars: The Clone Wars  450,000  TV Show   United States  10/03/2008
# 7                    Doctor Who  250,000  TV Show  United Kingdom  03/26/2005
# 16             Ready Player One   95,000    Movie   United States  03/28/2018
# 18                 Black Mirror   91,000  TV Show  United Kingdom  12/04/2011
# 25                      Gravity   58,000    Movie   United States  10/04/2013
# 27                  Snowpiercer   55,000  TV Show   United States  05/17/2020
# 30                 Interstellar   52,000    Movie   United States  11/05/2014
# 34                      Firefly   34,000  TV Show   United States  09/20/2002
# 35                      The 100   33,000  TV Show   United States  03/19/2014
# 39                  The X-Files   26,000  TV Show   United States  09/10/1993
# 50                       WALL-E   16,000    Movie   United States  06/22/2008
# ...

# %%
kidz.to_csv('kidz.csv')

# %%
kidz.dtypes
# Out:
# Unnamed: 0          int64
# title              object
# view               object
# category           object
# country            object
# premiere           object
# genre              object
# generation         object
# gender             object
# viewing_country    object
# dtype: object

# %%
connection.execute('select * from flix_shows')

# %%
a=pd.read_sql_query('select * from flix_shows',connection)

# %%
a
# Out:
#                             title       view   category        country  \
# 0                         Friends  7,700,000    TV Show  United States
# 1                             Rio  1,800,000      Movie  United States
# 2                    The Simpsons  1,300,000    TV Show  United States
# 3                    Supernatural  1,200,000    TV Show  United States
# 4                         Vikings  1,100,000    TV Show        Ireland
# ...                           ...        ...        ...            ...
# 11286     All the President's Men      1,000      Movie  United States
# 11287              Gone Baby Gone      1,000      Movie  United States
# 11288          Monsters vs Aliens      1,000      Movie  United States
# 11289  Best Exotic Marigold Hotel      1,000  Franchise  United States
# 11290              Into the Woods          0      Movie  United States
#
#           premiere                       genre    generation gender  \
# ...

# %%
kidz
# Out:
#                          title     view category         country    premiere  \
# 0                Tom and Jerry  820,000  TV Show   United States  02/10/1940
# 1    Star Wars: The Clone Wars  450,000  TV Show   United States  10/03/2008
# 2                        Mulan  390,000    Movie   United States  06/18/1998
# 3              The Dark Knight  355,100    Movie   United States  07/16/2008
# 4                        Arrow  330,000  TV Show   United States  10/10/2012
# ..                         ...      ...      ...             ...         ...
# 155          We're the Millers    1,200    Movie   United States  08/07/2013
# 156           Raised by Wolves    1,000  TV Show   United States  09/03/2020
# 157             Calendar Girls    1,000    Movie  United Kingdom  09/02/2003
# 158                Constantine    1,000  TV Show   United States  10/24/2014
# 159             Into the Woods        0    Movie   United States  12/25/2014
#
# ...

# %%
b=pd.concat([a,kidz])

# %%
kidz.drop('Unnamed: 0',axis=1,inplace=True)
kidz
# Out:
#                          title     view category         country    premiere  \
# 0                Tom and Jerry  820,000  TV Show   United States  02/10/1940
# 1    Star Wars: The Clone Wars  450,000  TV Show   United States  10/03/2008
# 2                        Mulan  390,000    Movie   United States  06/18/1998
# 3              The Dark Knight  355,100    Movie   United States  07/16/2008
# 4                        Arrow  330,000  TV Show   United States  10/10/2012
# ..                         ...      ...      ...             ...         ...
# 155          We're the Millers    1,200    Movie   United States  08/07/2013
# 156           Raised by Wolves    1,000  TV Show   United States  09/03/2020
# 157             Calendar Girls    1,000    Movie  United Kingdom  09/02/2003
# 158                Constantine    1,000  TV Show   United States  10/24/2014
# 159             Into the Woods        0    Movie   United States  12/25/2014
#
# ...

# %%
kidz=pd.read_csv('kidz.csv')

# %%
d.to_sql('flix_shows_kidz', connection, if_exists='fail',index=False)

# %%
kidz.drop('Unnamed: 0',axis=1,inplace=True)

# %%
kidz['generation']='kids'

# %%
kidz
# Out:
#                          title     view category         country    premiere  \
# 0                Tom and Jerry  820,000  TV Show   United States  02/10/1940
# 1    Star Wars: The Clone Wars  450,000  TV Show   United States  10/03/2008
# 2                        Mulan  390,000    Movie   United States  06/18/1998
# 3              The Dark Knight  355,100    Movie   United States  07/16/2008
# 4                        Arrow  330,000  TV Show   United States  10/10/2012
# ..                         ...      ...      ...             ...         ...
# 155          We're the Millers    1,200    Movie   United States  08/07/2013
# 156           Raised by Wolves    1,000  TV Show   United States  09/03/2020
# 157             Calendar Girls    1,000    Movie  United Kingdom  09/02/2003
# 158                Constantine    1,000  TV Show   United States  10/24/2014
# 159             Into the Woods        0    Movie   United States  12/25/2014
#
# ...

# %%
pd.read_sql('select * from flix_shows_kidz',connection)
# Out:
#        index              title       view category         country  \
# 0          0            Friends  7,700,000  TV Show   United States
# 1          1                Rio  1,800,000    Movie   United States
# 2          2       The Simpsons  1,300,000  TV Show   United States
# 3          3       Supernatural  1,200,000  TV Show   United States
# 4          4            Vikings  1,100,000  TV Show         Ireland
# ...      ...                ...        ...      ...             ...
# 11446    155  We're the Millers      1,200    Movie   United States
# 11447    156   Raised by Wolves      1,000  TV Show   United States
# 11448    157     Calendar Girls      1,000    Movie  United Kingdom
# 11449    158        Constantine      1,000  TV Show   United States
# 11450    159     Into the Woods          0    Movie   United States
#
#          premiere                                   genre    generation  \
# 0      09/22/1994                          |Comedy|Sitcom  generation-z
# ...

# %%
connection('alter table flix_shows_kidz2 rename to flix_shows_kidz')

# %%
pd.read_sql('delete from flix_shows_kidz where title like "%Aqu%"',connection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-251-7fdba4eb3c54> in <module>
# ----> 1 pd.read_sql('delete from flix_shows_kidz where title like "%Aqu%"',connection)
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     410             coerce_float=coerce_float,
#     411             parse_dates=parse_dates,
# --> 412             chunksize=chunksize,
#     413         )
#     414
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1632         args = _convert_params(sql, params)
#    1633         cursor = self.execute(*args)
# -> 1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
# ...

# %%
pd.read_sql('select * from flix_shows_kidz where title like "%Aq"',connection)
# Out:
# Empty DataFrame
# Columns: [index, title, view, category, country, premiere, genre, generation, gender, viewing_country]
# Index: []

# %%
for row in connection.execute('select * from flix_shows_kidz where title like "%Aq%"'):
    print(row)

# %%
pd.read_sql('select * from flix_shows_kidz where title like "%Clone%"',connection)
# Out:
#     index                  title     view category        country    premiere  \
# 0      61  Star Wars: Clone Wars   70,000  TV Show  United States  10/03/2008
# 1     214  Star Wars: Clone Wars    2,200  TV Show  United States  10/03/2008
# 2     344  Star Wars: Clone Wars   82,000  TV Show  United States  10/03/2008
# 3     487  Star Wars: Clone Wars   17,000  TV Show  United States  10/03/2008
# 4     586  Star Wars: Clone Wars   32,000  TV Show  United States  10/03/2008
# ..    ...                    ...      ...      ...            ...         ...
# 61  10706  Star Wars: Clone Wars   32,000  TV Show  United States  10/03/2008
# 62  10889  Star Wars: Clone Wars  290,000  TV Show  United States  10/03/2008
# 63  11129  Star Wars: Clone Wars  140,000  TV Show  United States  10/03/2008
# 64      1  Star Wars: Clone Wars  450,000  TV Show  United States  10/03/2008
# 65     94  Star Wars: Clone Wars  385,000  TV Show  United States  10/03/2008
#
# ...

# %%
connection.commit()

# %%
connection.execute("drop table flix_shows_kidz")

# %%
for row in connection.execute('select * from flix_shows'):
    print(row)
# Out:
# ('Friends', '7,700,000', 'TV Show', 'United States', '09/22/1994', '|Comedy|Sitcom', 'generation-z', 'men', 'brazil')
# ('Rio', '1,800,000', 'Movie', 'United States', '04/15/2011', '|Animated|For Girls', 'generation-z', 'men', 'brazil')
# ('The Simpsons', '1,300,000', 'TV Show', 'United States', '12/17/1989', '|Animation|Adult Animation', 'generation-z', 'men', 'brazil')
# ('Supernatural', '1,200,000', 'TV Show', 'United States', '09/13/2005', '|Fantasy|Supernatural', 'generation-z', 'men', 'brazil')
# ('Vikings', '1,100,000', 'TV Show', 'Ireland', '03/03/2013', '|History|Vikings', 'generation-z', 'men', 'brazil')
# ('Game of Thrones', '850,000', 'TV Show', 'United States', '04/17/2011', '| HBO|Fantasy|Dragons', 'generation-z', 'men', 'brazil')
# ('The Witcher', '840,000', 'TV Show', 'United States', '12/20/2019', '| Netflix|Fantasy|Wizards', 'generation-z', 'men', 'brazil')
# ...

# %%
connection.execute("Update flix_shows_kidz set genre='|Science Fiction|Space' where title like '%Star Wars%'")

# %%
d.drop('index',axis=1,inplace=True)

# %%
pd.read_sql('select * from flix_shows_kidz where title like "%Star%"',connection)
# Out:
#                      title     view category        country    premiere  \
# 0    Star Wars: Clone Wars   70,000  TV Show  United States  10/03/2008
# 1    Star Wars: Clone Wars    2,200  TV Show  United States  10/03/2008
# 2    Star Wars: Clone Wars   82,000  TV Show  United States  10/03/2008
# 3    Star Wars: Clone Wars   17,000  TV Show  United States  10/03/2008
# 4    Star Wars: Clone Wars   32,000  TV Show  United States  10/03/2008
# ..                     ...      ...      ...            ...         ...
# 85   Star Wars: Clone Wars  290,000  TV Show  United States  10/03/2008
# 86  The Fault in Our Stars  790,800    Movie  United States  05/16/2014
# 87   Star Wars: Clone Wars  140,000  TV Show  United States  10/03/2008
# 88   Star Wars: Clone Wars  450,000  TV Show  United States  10/03/2008
# 89   Star Wars: Clone Wars  385,000  TV Show  United States  10/03/2008
#
#                      genre    generation gender viewing_country
# ...

# %%
connection.commit()

# %%
pd.read_sql('select * from flix_shows',connection)
# Out:
#                             title       view   category        country  \
# 0                         Friends  7,700,000    TV Show  United States
# 1                             Rio  1,800,000      Movie  United States
# 2                    The Simpsons  1,300,000    TV Show  United States
# 3                    Supernatural  1,200,000    TV Show  United States
# 4                         Vikings  1,100,000    TV Show        Ireland
# ...                           ...        ...        ...            ...
# 11286     All the President's Men      1,000      Movie  United States
# 11287              Gone Baby Gone      1,000      Movie  United States
# 11288          Monsters vs Aliens      1,000      Movie  United States
# 11289  Best Exotic Marigold Hotel      1,000  Franchise  United States
# 11290              Into the Woods          0      Movie  United States
#
#           premiere                       genre    generation gender  \
# ...
